# %%
bak = float(input("Lütfen Makineye para atınız : "))

print(f"Teşekkürler ; güncel bakiyeniz : {bak} €")

if bak >= 1.5:
    print("")
    sec = input("Çay mi istersiniz? \nKahve mi istersiniz ? :")
    print("")
    if sec.title() == "Çay":
        print("Çayınız hazırlanıyor; Para üstünüz : ", bak - 1,"€")
    elif sec.title() == "Kahve":
        print("Kahveniz hazırlanıyor; Para üstünüz : ", bak - 1.5,"€")
elif bak >= 1 and bak <1.5:
    sec = input("Bakiyeniz ile sadece çay alabilirsiniz \nçay ister misiniz??")
    if sec.title() == "Hayır":
        print("Para üstünüz iade ediliyor! :", bak,"€")
    elif sec.title() == "Evet":
        print("Çayınız hazırlanıyor; para üstünüz : ", bak - 1,"€")
elif bak < 1:
    sec = input("Bakiyeniz yetersiz; para eklemek ister misiniz ?")
    if sec.title() == "Hayır":
        print("Paranız iade ediliyor.",bak,"€")
    elif sec.title() == "Evet":
        bak_ek = float(input("Lütfen para ekleyiniz :"))
        bak += bak_ek
        print(f"Yeni bakiyeniz : {bak}")
        if bak < 1:
            print("Üzgünüz Bakiyeniz yeterli değil; Para üstünüz", bak)
        elif bak >= 1.5:
            sec = input("Çay mı istersiniz, Kahve mi istersiniz:")
            if sec.title() == "Kahve":
                print("Kahveniz hazırlanıyor; para üstünüz : ",bak - 1.5,"€")
            elif sec.title() == "Çay":
                print("Çayınız hazırlanıyor; para üstünüz : ", bak - 1,"€")
        elif bak >= 1 and bak < 1.5:
            sec = input("Bakiyeniz sadece çay almaya yetiyor; çay ister misiniz: ")
            if sec.title() == "Hayır":
                print("Teşekkür buyrun para üstünüz : ", bak,"€")
            elif sec.title() == "Evet":
                print("Çayınız hazırlanıyor!, Para üstünüz :",bak - 1,"€")
    else:
        sec = input("Lütfen 'Evet' ya da 'Hayır' giriniz :")
        if sec.title() == "Hayır":
            print("Teşekkürler!, Para üstünüz : ", bak,"€")
        elif sec.title() == "Evet":
            print("")
# Out:
# Lütfen Makineye para atınız : 0.5
# Teşekkürler ; güncel bakiyeniz : 0.5 €
# Bakiyeniz yetersiz; para eklemek ister misiniz ?evet
# Lütfen para ekleyiniz :0.75
# Yeni bakiyeniz : 1.25
# Bakiyeniz sadece çay almaya yetiyor; çay ister misiniz: hayır
# Teşekkür buyrun para üstünüz :  1.25 €

# %%
bak = float(input("Lütfen Makineye para atınız : "))

print(f"Teşekkürler ; güncel bakiyeniz : {bak} €")

while True:
    if bak >= 1.5:
        print("")
        sec = input("Çay mi istersiniz? \nKahve mi istersiniz ? :")
        print("")
        if sec.title() == "Çay":
            print("Çayınız hazırlanıyor; Para üstünüz : ", bak - 1,"€")
            break
        elif sec.title() == "Kahve":
            print("Kahveniz hazırlanıyor; Para üstünüz : ", bak - 1.5,"€")
            break
    elif bak >= 1 and bak <1.5:
        sec = input("Bakiyeniz ile sadece çay alabilirsiniz \nçay ister misiniz??")
        if sec.title() == "Hayır":
            print("Para üstünüz iade ediliyor! :", bak,"€")
            break
        elif sec.title() == "Evet":
            print("Çayınız hazırlanıyor; para üstünüz : ", bak - 1,"€")
            break
    elif bak < 1:
        sec = input("Bakiyeniz yetersiz; para eklemek ister misiniz ?")
        if sec.title() == "Hayır":
            print("Paranız iade ediliyor.",bak,"€")
            break
        elif sec.title() == "Evet":
            bak_ek = float(input("Lütfen para ekleyiniz :"))
            bak += bak_ek
            print(f"Yeni bakiyeniz : {bak}")
            if bak < 1:
                print("Üzgünüz Bakiyeniz yeterli değil; Para üstünüz", bak)
            elif bak >= 1.5:
                sec = input("Çay mı istersiniz, Kahve mi istersiniz:")
                if sec.title() == "Kahve":
                    print("Kahveniz hazırlanıyor; para üstünüz : ",bak - 1.5,"€")
                    break
                elif sec.title() == "Çay":
                    print("Çayınız hazırlanıyor; para üstünüz : ", bak - 1,"€")
                    break
            elif bak >= 1 and bak < 1.5:
                sec = input("Bakiyeniz sadece çay almaya yetiyor; çay ister misiniz: ")
                if sec.title() == "Hayır":
                    print("Teşekkür buyrun para üstünüz : ", bak,"€")
                    break
                elif sec.title() == "Evet":
                    print("Çayınız hazırlanıyor!, Para üstünüz :",bak - 1,"€")
                    break
        else:
            sec = input("Lütfen 'Evet' ya da 'Hayır' giriniz :")
            if sec.title() == "Hayır":
                print("Teşekkürler!, Para üstünüz : ", bak,"€")
                break
            elif sec.title() == "Evet":
                print("")
else:
    print()
